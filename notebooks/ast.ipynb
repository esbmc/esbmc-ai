# %% [markdown]
# # Test LLVM AST Notebook
#
# ## Author: Yiannis Charalambous

# %%
import os
from clang.cindex import Config
import clang.native
import clang.cindex
import sys
from typing import NamedTuple

# %%
# Connect the Python API of Clang to the libclang.so file bundled in the libclang PyPI package.
Config.library_file = os.path.join(
    os.path.dirname(clang.native.__file__),
    "libclang.so",
)

module_path = os.path.abspath(os.path.join(".."))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
FILE = "../samples/threading.c"


def get_declarations_local(root: clang.cindex.Cursor) -> list[clang.cindex.Cursor]:
    declarations: list[clang.cindex.Cursor] = []
    declarations_raw: set[str] = {}
    # Scan all direct symbols in root.
    for child in root.get_children():
        # print(f"Scanning: {child.spelling}")
        node: clang.cindex.Cursor = child
        kind: clang.cindex.CursorKind = node.kind
        # Check if it is actually from the file.
        if (
            kind.is_declaration()
            and node.storage_class == clang.cindex.StorageClass.NONE
        ):
            print(
                f"Found {node.spelling} [line={node.location.line}, col={node.location.column}]"
            )
            loc: clang.cindex.SourceRange = node.extent
            end: clang.cindex.SourceLocation = loc.end
            start: clang.cindex.SourceLocation = loc.start
            print(
                f"Start: {start.offset}, End: {end.offset}, Range: {end.offset - start.offset}"
            )
            print()
            declarations.append(node)
    return declarations


index: clang.cindex.Index = clang.cindex.Index.create()
tu: clang.cindex.TranslationUnit = index.parse(FILE)
root: clang.cindex.Cursor = tu.cursor
declarations: clang.cindex.Cursor = get_declarations_local(root)

print(f"Total {len(declarations)}")
# Out:
# Found a [line=4, col=5]
# Start: 42, End: 47, Range: 5
#
# Found b [line=4, col=8]
# Start: 42, End: 50, Range: 8
#
# Found __VERIFIER_atomic_acquire [line=5, col=6]
# Start: 52, End: 134, Range: 82
#
# Found c [line=10, col=7]
# Start: 135, End: 224, Range: 89
#
# Found d [line=17, col=11]
# Start: 225, End: 236, Range: 11
#
# Found main [line=18, col=5]
# Start: 238, End: 363, Range: 125
#
# Total 6

# %% [markdown]
# ## Reversing Reach AST To Source Code
#
# The only issue I have found, multiple declarations in one statement need to be recognized and the nodes combined:
#
# ```c
# int a, b;
# ```

# %%
with open(FILE) as file:
    source_code: str = file.read()


def get_node_source_code(source_code: str, node: clang.cindex.Cursor) -> str:
    loc: clang.cindex.SourceRange = node.extent
    start: clang.cindex.SourceLocation = loc.start
    end: clang.cindex.SourceLocation = loc.end
    return source_code[start.offset : end.offset]


for node in declarations:
    print(f"Code for {node.displayname}:")
    print("```")
    print(get_node_source_code(source_code, node))
    print("```")
    print()
# Out:
# Code for a:
# ```
# int a
# ```
#
# Code for b:
# ```
# int a, b
# ```
#
# Code for __VERIFIER_atomic_acquire():
# ```
# void __VERIFIER_atomic_acquire(void)
# {
#     __VERIFIER_assume(a == 0);
#     a = 1;
# }
# ```
#
# Code for c(void *):
# ```
# void *c(void *arg)
# {
#     ;
#     __VERIFIER_atomic_acquire();
#     b = 1;
#     return NULL;
# }
# ```
#
# Code for d:
# ```
# pthread_t d
# ```
#
# Code for main():
# ```
# int main()
# {
#     pthread_create(&d, 0, c, 0);
#     __VERIFIER_atomic_acquire();
#     if (!b)
#         assert(0);
#     return 0;
# }
# ```

# %% [markdown]
# # Test Code

# %%
from esbmc_ai_lib.frontend.ast import ClangAST

# %%
file = "../samples/threading.c"
cast = ClangAST(file)
functions = cast.get_fn_decl()

for fn in functions:
    print(str(fn) + "\n")
    # Seems like different cursors have the same translation unit...
    print(fn.cursor)
    print(fn.cursor.translation_unit)
# Out:
# __VERIFIER_atomic_acquire()
#
# <clang.cindex.Cursor object at 0x7f0cba6b0f80>
# <clang.cindex.TranslationUnit object at 0x7f0cd0400e10>
# c(arg: void *)
#
# <clang.cindex.Cursor object at 0x7f0cba6b1010>
# <clang.cindex.TranslationUnit object at 0x7f0cd0400e10>
# main()
#
# <clang.cindex.Cursor object at 0x7f0cba6b1130>
# <clang.cindex.TranslationUnit object at 0x7f0cd0400e10>

# %% [markdown]
# # Test Code 2

# %%
file = "./samples/typedefs.c"
cast = ClangAST(file)
functions = cast.get_all_decl()

for fn in functions:
    print(fn)
# Out:
# main()
# typedef (_Float32) float {}
# typedef (_Float64) double {}
# typedef (_Float32x) double {}
# typedef (_Float64x) long double {}
# typedef () div_t {}
# typedef (div_t) div_t {}
# typedef () ldiv_t {}
# typedef (ldiv_t) ldiv_t {}
# typedef () lldiv_t {}
# typedef (lldiv_t) lldiv_t {}
# typedef (__u_char) unsigned char {}
# typedef (__u_short) unsigned short {}
# typedef (__u_int) unsigned int {}
# typedef (__u_long) unsigned long {}
# typedef (__int8_t) signed char {}
# typedef (__uint8_t) unsigned char {}
# typedef (__int16_t) short {}
# typedef (__uint16_t) unsigned short {}
# typedef (__int32_t) int {}
# typedef (__uint32_t) unsigned int {}
# typedef (__int64_t) long {}
# typedef (__uint64_t) unsigned long {}
# typedef (__int_least8_t) signed char {}
# typedef (__uint_least8_t) unsigned char {}
# typedef (__int_least16_t) short {}
# typedef (__uint_least16_t) unsigned short {}
# typedef (__int_least32_t) int {}
# typedef (__uint_least32_t) unsigned int {}
# typedef (__int_least64_t) long {}
# typedef (__uint_least64_t) unsigned long {}
# typedef (__quad_t) long {}
# typedef (__u_quad_t) unsigned long {}
# typedef (__intmax_t) long {}
# typedef (__uintmax_t) unsigned long {}
# typedef (__dev_t) unsigned long {}
# typedef (__uid_t) unsigned int {}
# typedef (__gid_t) unsigned int {}
# typedef (__ino_t) unsigned long {}
# typedef (__ino64_t) unsigned long {}
# typedef (__mode_t) unsigned int {}
# typedef (__nlink_t) unsigned long {}
# typedef (__off_t) long {}
# typedef (__off64_t) long {}
# typedef (__pid_t) int {}
# typedef () __fsid_t {}
# typedef (__fsid_t) __fsid_t {}
# typedef (__clock_t) long {}
# typedef (__rlim_t) unsigned long {}
# typedef (__rlim64_t) unsigned long {}
# typedef (__id_t) unsigned int {}
# typedef (__time_t) long {}
# typedef (__useconds_t) unsigned int {}
# typedef (__suseconds_t) long {}
# typedef (__suseconds64_t) long {}
# typedef (__daddr_t) int {}
# typedef (__key_t) int {}
# typedef (__clockid_t) int {}
# typedef (__timer_t) void * {}
# typedef (__blksize_t) long {}
# typedef (__blkcnt_t) long {}
# typedef (__blkcnt64_t) long {}
# typedef (__fsblkcnt_t) unsigned long {}
# typedef (__fsblkcnt64_t) unsigned long {}
# typedef (__fsfilcnt_t) unsigned long {}
# typedef (__fsfilcnt64_t) unsigned long {}
# typedef (__fsword_t) long {}
# typedef (__ssize_t) long {}
# typedef (__syscall_slong_t) long {}
# typedef (__syscall_ulong_t) unsigned long {}
# typedef (__loff_t) long {}
# typedef (__caddr_t) char * {}
# typedef (__intptr_t) long {}
# typedef (__socklen_t) unsigned int {}
# typedef (__sig_atomic_t) int {}
# typedef (u_char) unsigned char {}
# typedef (u_short) unsigned short {}
# typedef (u_int) unsigned int {}
# typedef (u_long) unsigned long {}
# typedef (quad_t) long {}
# typedef (u_quad_t) unsigned long {}
# typedef (fsid_t) __fsid_t {}
# typedef (loff_t) long {}
# typedef (ino_t) unsigned long {}
# typedef (dev_t) unsigned long {}
# typedef (gid_t) unsigned int {}
# typedef (mode_t) unsigned int {}
# typedef (nlink_t) unsigned long {}
# typedef (uid_t) unsigned int {}
# typedef (off_t) long {}
# typedef (pid_t) int {}
# typedef (id_t) unsigned int {}
# typedef (ssize_t) long {}
# typedef (daddr_t) int {}
# typedef (caddr_t) char * {}
# typedef (key_t) int {}
# typedef (clock_t) long {}
# typedef (clockid_t) int {}
# typedef (time_t) long {}
# typedef (timer_t) void * {}
# typedef (ulong) unsigned long {}
# typedef (ushort) unsigned short {}
# typedef (uint) unsigned int {}
# typedef (int8_t) signed char {}
# typedef (int16_t) short {}
# typedef (int32_t) int {}
# typedef (int64_t) long {}
# typedef (u_int8_t) unsigned char {}
# typedef (u_int16_t) unsigned short {}
# typedef (u_int32_t) unsigned int {}
# typedef (u_int64_t) unsigned long {}
# typedef (register_t) long {}
# typedef () __sigset_t {}
# typedef (__sigset_t) __sigset_t {}
# typedef (sigset_t) __sigset_t {}
# typedef () struct timeval {}
# typedef () struct timespec {}
# typedef (suseconds_t) long {}
# typedef (__fd_mask) long {}
# typedef () fd_set {}
# typedef (fd_set) fd_set {}
# typedef (fd_mask) long {}
# typedef (blksize_t) long {}
# typedef (blkcnt_t) long {}
# typedef (fsblkcnt_t) unsigned long {}
# typedef (fsfilcnt_t) unsigned long {}
# typedef () __atomic_wide_counter {}
# typedef (__atomic_wide_counter) __atomic_wide_counter {}
# typedef () struct __pthread_internal_list {}
# typedef (__pthread_list_t) struct __pthread_internal_list {}
# typedef () struct __pthread_internal_slist {}
# typedef (__pthread_slist_t) struct __pthread_internal_slist {}
# typedef () struct __pthread_mutex_s {}
# typedef () struct __pthread_rwlock_arch_t {}
# typedef () struct __pthread_cond_s {}
# typedef (__tss_t) unsigned int {}
# typedef (__thrd_t) unsigned long {}
# typedef () __once_flag {}
# typedef (__once_flag) __once_flag {}
# typedef (pthread_t) unsigned long {}
# typedef () pthread_mutexattr_t {}
# typedef (pthread_mutexattr_t) pthread_mutexattr_t {}
# typedef () pthread_condattr_t {}
# typedef (pthread_condattr_t) pthread_condattr_t {}
# typedef (pthread_key_t) unsigned int {}
# typedef (pthread_once_t) int {}
# typedef () union pthread_attr_t {}
# typedef (pthread_attr_t) union pthread_attr_t {}
# typedef () pthread_mutex_t {}
# typedef (pthread_mutex_t) pthread_mutex_t {}
# typedef () pthread_cond_t {}
# typedef (pthread_cond_t) pthread_cond_t {}
# typedef () pthread_rwlock_t {}
# typedef (pthread_rwlock_t) pthread_rwlock_t {}
# typedef () pthread_rwlockattr_t {}
# typedef (pthread_rwlockattr_t) pthread_rwlockattr_t {}
# typedef (pthread_spinlock_t) volatile int {}
# typedef () pthread_barrier_t {}
# typedef (pthread_barrier_t) pthread_barrier_t {}
# typedef () pthread_barrierattr_t {}
# typedef (pthread_barrierattr_t) pthread_barrierattr_t {}
# typedef () struct random_data {}
# typedef () struct drand48_data {}
# typedef (__compar_fn_t) int (*)(const void *, const void *) {}
# typedef () struct linear {}
# typedef (LinearTypeDef) struct linear {}
# typedef () Point {}
# typedef (Point) Point {}
# typedef (Typest) enum Types {}
# typedef () union Combines {}
# typedef (CombinesTypeDef) union Combines {}
# a:Point
# b:Point *
# c:int
# d:char *
# e:enum Types
# f:Typest
# Types:enum

# %%
file = "./samples/typedefs.c"
cast: ClangAST = ClangAST(file)
includes = cast.get_include_directives()

for include in includes:
    print(include)
# Out:
# #include "/usr/include/stdlib.h"
# #include "/usr/include/assert.h"
